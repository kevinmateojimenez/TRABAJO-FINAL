# %% [markdown]
# Medellín, Colombia 27 de abril de 2026
# <table style="border: none; border-collapse: collapse; width: 100%;">
#     <tr style="border: none;">
#         <td style="border: none; width: 120px; vertical-align: middle;">
#             <img src="img/logo.png" style="width: 100px;"/>
#         </td>
#         <td style="border: none; vertical-align: middle;">
#             <div style="color:#BA352C; font-size: 32px; font-weight: bold; line-height: 1.2;">
#                 Universidad Autónoma Latinoamericana
#             </div>
#             <div style="color:#FC9C28; font-size: 26px; font-weight: bold; line-height: 1.2;">
#                 Especialización en Analítica de Datos - Grupo 2
#             </div>
#         </td>
#     </tr>
# </table>
#
# <span style="font-size: 18px;">Entregable Final de la Asignatura: Principios analíticos para la ciencia de datos</span>
#
# <span style="font-size: 24px; font-weight: bold;">Integrantes</span>
#
# - Evelin Dahiana Franco Campiño
# - Kevin Mateo Jiménez Guisao
# - Nicolle Gaviria Mejía
#
# </br>
#
# ***

# %% [markdown]
# <div>
#     <span style=" font-size: xxx-large; font-weight: bold;"> Análisis Exploratorio de Datos (EDA) </span>
# </div>
# <div >
#     <span style=" font-size: xx-large; font-weight: bold;">Salud mental estudiantil y síndrome de burnout </span>
# </div>

# %% [markdown]
# ## 1. 📄 Introducción
#
# <p>
#     El Conjunto de Datos sobre Salud Mental y Agotamiento Estudiantil (20 características) es una base de datos a gran escala diseñada para analizar y predecir los niveles de burnout (agotamiento) estudiantil basándose en factores académicos, psicológicos y de estilo de vida.
# </p>
#
# > Este conjunto de datos contiene aproximadamente 150 mil registros de estudiantes con una combinación de variables numéricas y categóricas, lo que lo hace ideal para tareas de aprendizaje automático (machine learning), clasificación y análisis de datos.

# %% [markdown]
# ## 2. 🧮 Conjunto de Datos
# **Características:**
# - Demografía: Edad, género, carrera y año académico.
#
# - Indicadores académicos: Promedio general (CGPA), asistencia y horas de estudio.
#
# - Puntajes psicológicos: Niveles de ansiedad, depresión y estrés.
#
# - Factores de estilo de vida: Horas de sueño, actividad física y tiempo frente a la pantalla.
#
# - Indicadores de estrés social y financiero.
#
# - Variable objetivo: `burnout_level` (nivel de agotamiento).

# %% [markdown]
# <table style="width: 500px; margin-left: 0; margin-right: auto;">
#     <thead>
#         <tr style="background-color: #BA352C; color: white;">
#             <th style="padding: 10px; text-align: left; border: 1px solid #ddd;">Información</th>
#             <th style="padding: 10px; text-align: left; border: 1px solid #ddd;">Detalle</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="background-color: #FC9C2833; font-weight: bold; padding: 8px; border: 1px solid #ddd; width: 150px;">Fuente</td>
#             <td style="padding: 8px; border: 1px solid #ddd; ; width: 350px;">
#                 <a href="https://www.kaggle.com/datasets/sehaj1104/student-mental-health-and-burnout-dataset/data" target="_blank">Kaggle - Dataset Link</a>
#             </td>
#         </tr>
#         <tr>
#             <td style="background-color: #FC9C2833; font-weight: bold; padding: 8px; border: 1px solid #ddd; width: 150px;">Nombre del dataset</td>
#             <td style="padding: 8px; border: 1px solid #ddd; width: 350px;">Student Mental Health and Burnout Dataset</td>
#         </tr>
#         <tr>
#             <td style="background-color: #FC9C2833; font-weight: bold; padding: 8px; border: 1px solid #ddd; width: 150px;">Propietario</td>
#             <td style="padding: 8px; border: 1px solid #ddd; width: 350px;">Mansehaj Preet</td>
#         </tr>
#         <tr>
#             <td style="background-color: #FC9C2833; font-weight: bold; padding: 8px; border: 1px solid #ddd; width: 150px;">Tipo de Origen</td>
#             <td style="padding: 8px; border: 1px solid #ddd; width: 350px;">Archivo CSV</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### 2.1 Importación del conjunto de datos

# %%
from IPython.core.display import Markdown
from IPython.core.display_functions import display
import pandas as pd
import numpy as np

# Cargar el conjunto de datos
path = "data/datos.csv"
df_raw = pd.read_csv(path, sep=",", header="infer")

# Crear una copia de trabajo
df = df_raw.copy()

# Total de filas
total_filas = len(df)
display(Markdown(f"Total de registros: {total_filas}"))
display(Markdown(f"#### **Muestra del conjunto de datos**"))
display(df.sample(n=10, ignore_index=True))
# Out:
# Total de registros: 150237
# #### **Muestra del conjunto de datos**
#    student_id   age  gender course year  daily_study_hours  daily_sleep_hours  \
# 0    21856612  18.0   Other    BBA  2nd                1.8                8.0
# 1    27840418  22.0  Female    MBA  2nd                8.3                7.8
# 2    16498858  24.0    Male    BCA  3rd                9.6                3.4
# 3    84615534  19.0   Other    MBA  2nd                7.2                6.3
# 4    45303696  20.0  Female    BSc  1st                6.0                7.8
# 5    59838037  17.0    Male    MBA  3rd                6.4                7.2
# 6    58075767  19.0  Female    BBA  4th                2.3                7.7
# 7    85064636  19.0  Female    MCA  3rd                6.5                8.2
# 8    88550425  25.0    Male    MCA  3rd                8.1                5.0
# 9    68033541  18.0   Other    BBA  2nd                5.5                7.7
#
#    screen_time_hours stress_level  anxiety_score  depression_score  \
# 0                4.5       Medium            3.0               6.0
# 1                6.4          Low           10.0               9.0
# 2                6.7         High            9.0               8.0
# 3                8.1         High            7.0               2.0
# 4                8.2          Low           10.0               3.0
# 5                6.2       Medium           10.0               4.0
# 6                2.1         High            6.0               9.0
# 7                9.8         High            4.0               2.0
# 8                7.2       Medium            3.0               8.0
# 9               11.2       Medium            8.0               6.0
#
#    academic_pressure_score  financial_stress_score  social_support_score  \
# 0                      2.0                       4                   5.0
# 1                      4.0                       9                   3.0
# 2                      7.0                       2                   2.0
# 3                     10.0                       5                   5.0
# 4                      5.0                       4                  10.0
# 5                      4.0                      10                   6.0
# 6                      5.0                       8                   8.0
# 7                      6.0                       3                   6.0
# 8                      6.0                      10                   2.0
# 9                      6.0                       8                   3.0
#
#    physical_activity_hours sleep_quality  attendance_percentage  cgpa  \
# 0                      1.1          Poor                   58.1  8.24
# 1                      1.1       Average                   80.7  4.16
# 2                      1.4          Good                   73.8  6.60
# 3                      2.0          Good                   54.3  7.11
# 4                      0.6          Poor                   60.2  8.48
# 5                      1.8          Good                   63.8  9.73
# 6                      1.5       Average                   87.2  7.04
# 7                      1.6       Average                   69.7  9.17
# 8                      1.0       Average                   66.2  9.91
# 9                      1.5          Poor                   73.1  6.15
#
#   internet_quality burnout_level
# 0          Average        Medium
# 1             Good          High
# 2             Good           Low
# 3             Poor           Low
# 4             Good           Low
# 5          Average        Medium
# 6          Average           Low
# 7             Poor           Low
# 8             Poor        Medium
# 9             Poor           Low

# %% [markdown]
# ### 2.2 Información de las columnas del conjunto de datos
#
# > Se creará un dataset nuevo que explique cada columna, cuántos valores no nulos contiene todo el conjunto y qué tipo de datos interpreta el sistema según su contenido.

# %%
# Crear un DataFrame de información para presentarlo

info_df = pd.DataFrame({
    'Columna': df.columns,
    'No Nulos': df.count().values,
    'Tipo de Dato': df.dtypes.values
})

display(info_df)
# Out:
#                     Columna  No Nulos Tipo de Dato
# 0                student_id    150237        int64
# 1                       age    150236      float64
# 2                    gender    150236          str
# 3                    course    150234          str
# 4                      year    150235          str
# 5         daily_study_hours    150233      float64
# 6         daily_sleep_hours    150236      float64
# 7         screen_time_hours    150237      float64
# 8              stress_level    150234          str
# 9             anxiety_score    150235      float64
# 10         depression_score    150236      float64
# 11  academic_pressure_score    150236      float64
# 12   financial_stress_score    150237        int64
# 13     social_support_score    150236      float64
# 14  physical_activity_hours    150236      float64
# 15            sleep_quality    150237          str
# 16    attendance_percentage    150234      float64
# 17                     cgpa    150236      float64
# 18         internet_quality    150235          str
# 19            burnout_level    150235          str

# %% [markdown]
# ### 2.3 📙 Diccionario de Datos
#
# <table style="width: 1200px; margin-left: 0; margin-right: auto;">
#     <thead style="background-color: #352cba80">
#         <tr>
#             <td><b>Columna</b></td>
#             <td><b>Formato</b></td>
#             <td><b>Descripción</b></td>
#             <td><b>Ejemplos Reales</b></td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td><b> student_id</b></td>
#             <td>Entero</td>
#             <td>Identificador único para cada estudiante.</td>
#             <td>73698903, 36386454 (Rango: 10000510 - 99999584)</td>
#         </tr>
#         <tr>
#             <td><b>age</b></td>
#             <td>Flotante</td>
#             <td>Edad del estudiante.</td>
#             <td>17.0, 20.0, 25.0</td>
#         </tr>
#         <tr>
#             <td><b>gender</b></td>
#             <td>Texto</td>
#             <td>Género del estudiante.</td>
#             <td>Male, Female, Other</td>
#         </tr>
#         <tr>
#             <td><b>course</b></td>
#             <td>Texto</td>
#             <td>
#                 Programa académico matriculado:<br>
#                 • <b>BTech:</b> Licenciatura en Tecnología<br>
#                 • <b>BSc:</b> Licenciatura en Ciencias<br>
#                 • <b>BCA:</b> Licenciatura en Aplicaciones Informáticas<br>
#                 • <b>BBA:</b> Licenciatura en Administración de Empresas<br>
#                 • <b>MCA:</b> Maestría en Aplicaciones Informáticas<br>
#                 • <b>MBA:</b> Maestría en Administración de Empresas
#             </td>
#             <td>BTech, BCA, BSc, MBA, MCA, BBA</td>
#         </tr>
#         <tr>
#             <td><b>year</b></td>
#             <td>Texto</td>
#             <td>Año de estudio del estudiante.</td>
#             <td>1st, 2nd, 3rd, 4th</td>
#         </tr>
#         <tr>
#             <td><b>daily_study_hours</b></td>
#             <td>Flotante</td>
#             <td>Tiempo promedio diario de estudio.</td>
#             <td>4.3, 1.4 (Rango: 1.0 - 10.0)</td>
#         </tr>
#         <tr>
#             <td><b>daily_sleep_hours</b></td>
#             <td>Flotante</td>
#             <td>Duración promedio diaria de sueño.</td>
#             <td>6.8, 4.7 (Rango: 4.0 - 9.0)</td>
#         </tr>
#         <tr>
#             <td><b>screen_time_hours</b></td>
#             <td>Flotante</td>
#             <td>Tiempo diario de exposición a pantallas.</td>
#             <td>6.1, 3.0 (Rango: 1.0 - 12.0)</td>
#         </tr>
#         <tr>
#             <td><b>stress_level</b></td>
#             <td>Texto</td>
#             <td>Categoría de estrés autorreportada.</td>
#             <td>High, Medium, Low</td>
#         </tr>
#         <tr>
#             <td><b>anxiety_score</b></td>
#             <td>Flotante</td>
#             <td>Puntaje de ansiedad (escala 1–10).</td>
#             <td>10.0, 2.0 (Rango: 1.0 - 10.0)</td>
#         </tr>
#         <tr>
#             <td><b>depression_score</b></td>
#             <td>Flotante</td>
#             <td>Puntaje de depresión (escala 1-10).</td>
#             <td>3.0, 10.0 (Rango: 1.0 - 10.0)</td>
#         </tr>
#         <tr>
#             <td><b>academic_pressure_score</b></td>
#             <td>Flotante</td>
#             <td>Puntaje de presión académica (escala 1-10).</td>
#             <td>4.0, 8.0 (Rango: 1.0 - 10.0)</td>
#         </tr>
#         <tr>
#             <td><b>financial_stress_score</b></td>
#             <td>Entero</td>
#             <td>Puntaje de estrés financiero (escala 1-10).</td>
#             <td>2, 5 (Rango: 1 - 10)</td>
#         </tr>
#         <tr>
#             <td><b>social_support_score</b></td>
#             <td>Flotante</td>
#             <td>Puntaje de apoyo social (escala 1-10).</td>
#             <td>6.0, 9.0 (Rango: 1.0 - 10.0)</td>
#         </tr>
#         <tr>
#             <td><b>physical_activity_hours</b></td>
#             <td>Flotante</td>
#             <td>Horas diarias de actividad física.</td>
#             <td>1.8, 1.9 (Rango: 0.0 - 2.0)</td>
#         </tr>
#         <tr>
#             <td><b>sleep_quality</b></td>
#             <td>Texto</td>
#             <td>Calidad del sueño reportada.</td>
#             <td>Good, Average, Poor</td>
#         </tr>
#         <tr>
#             <td><b>attendance_percentage</b></td>
#             <td>Flotante</td>
#             <td>Porcentaje de asistencia a clases.</td>
#             <td>66.5, 55.8 (Rango: 50.0 - 100.0)</td>
#         </tr>
#         <tr>
#             <td><b>cgpa</b></td>
#             <td>Flotante</td>
#             <td>Promedio de calificaciones acumulado (CGPA).</td>
#             <td>9.63, 6.04 (Rango: 4.0 - 10.0)</td>
#         </tr>
#         <tr>
#             <td><b>internet_quality</b></td>
#             <td>Texto</td>
#             <td>Calidad de la conexión a internet.</td>
#             <td>Good, Average, Poor</td>
#         </tr>
#         <tr>
#             <td><b>burnout_level</b></td>
#             <td>Texto</td>
#             <td>Nivel de agotamiento (burnout).</td>
#             <td>High, Medium, Low</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## 3. 📈 Resumen Estadístico
#
# > Antes de proceder con el análisis, se debe omitir
#  la columna `student_id` dado que esta representa un identificador por fila y no sería productiva ninguna función de agregación en este campo

# %%
# Crear un nuevo conjunto de datos sin la columna student_id

df_stats = df.drop("student_id", axis=1)

# Usar la función describe para generar un resumen estadístico general

display(df_stats.describe())
# Out:
#                  age  daily_study_hours  daily_sleep_hours  screen_time_hours  \
# count  150236.000000      150233.000000      150236.000000      150237.000000
# mean       21.255132           5.620371           6.702525           6.512841
# std         4.477762           2.920738           1.937215           3.187154
# min        16.000000           1.000000           2.000000           1.000000
# 25%        19.000000           3.300000           5.300000           3.800000
# 50%        21.000000           5.500000           6.700000           6.500000
# 75%        23.000000           7.800000           8.100000           9.300000
# max        98.000000          27.975540          12.000000          14.996863
#
#        anxiety_score  depression_score  academic_pressure_score  \
# count  150235.000000     150236.000000            150236.000000
# mean        5.493667          5.497597                 5.507548
# std         2.872731          2.868849                 2.875639
# min         1.000000          1.000000                 1.000000
# 25%         3.000000          3.000000                 3.000000
# 50%         5.000000          5.000000                 6.000000
# 75%         8.000000          8.000000                 8.000000
# max        10.000000         10.000000                10.000000
#
#        financial_stress_score  social_support_score  physical_activity_hours  \
# count           150237.000000         150236.000000            150236.000000
# mean                 5.496429              5.516314                 0.998273
# std                  2.864708              2.870492                 0.578878
# min                  1.000000              1.000000                 0.000000
# 25%                  3.000000              3.000000                 0.500000
# 50%                  6.000000              6.000000                 1.000000
# 75%                  8.000000              8.000000                 1.500000
# max                 10.000000             10.000000                 2.000000
#
#        attendance_percentage           cgpa
# count          150234.000000  150236.000000
# mean               75.010507       6.997502
# std                14.409744       1.732294
# min                50.000000       4.000000
# 25%                62.500000       5.500000
# 50%                75.000000       6.990000
# 75%                87.500000       8.500000
# max               100.000000      10.000000

# %% [markdown]
# <a id="calidad-datos"></a>
#
# ## 4. ✅ Calidad de los datos

# %% [markdown]
# Antes de realizar un análisis exhaustivo de los datos, primero evaluaremos qué tan fiables son, revisando datos vacíos, valores improbables y valores duplicados.

# %% [markdown]
# ### 4.1 Datos Faltantes (Nulos)

# %%
# 1. Calcular la cantidad de valores nulos
nulos = df.isnull().sum()

# 2. Filtrar únicamente las columnas que contienen valores nulos
nulos_filtrados = nulos[nulos > 0]

# 3. Validar si hay resultados para mostrar
if not nulos_filtrados.empty:
    # Convertir a DataFrame y luego a formato Markdown
    tabla_nulos_md = nulos_filtrados.to_frame(name="Valores Nulos").to_markdown()
    
    display(Markdown("### Columnas con Valores Nulos"))
    display(Markdown(tabla_nulos_md))
else:
    display(Markdown("### No hay valores nulos en el DataFrame 🎉"))
# Out:
# ### Columnas con Valores Nulos
# |                         |   Valores Nulos |
# |:------------------------|----------------:|
# | age                     |               1 |
# | gender                  |               1 |
# | course                  |               3 |
# | year                    |               2 |
# | daily_study_hours       |               4 |
# | daily_sleep_hours       |               1 |
# | stress_level            |               3 |
# | anxiety_score           |               2 |
# | depression_score        |               1 |
# | academic_pressure_score |               1 |
# | social_support_score    |               1 |
# | physical_activity_hours |               1 |
# | attendance_percentage   |               3 |
# | cgpa                    |               1 |
# | internet_quality        |               2 |
# | burnout_level           |               2 |

# %%
# Filtrar el DataFrame para obtener solo las filas con algún valor nulo
df_filas_nulas = df[df.isnull().any(axis=1)]
# Mostrar el mensaje superior
display(Markdown(f"**Mostrando {len(df_filas_nulas)} filas que contienen al menos un valor nulo:**"))
# Aplicar un estilo para resaltar los nulos en amarillo y mostrar la tabla
display(df_filas_nulas.style.highlight_null(color='yellow'))
# Out:
# **Mostrando 13 filas que contienen al menos un valor nulo:**
# <style type="text/css">
# #T_3160e_row0_col5, #T_3160e_row1_col6, #T_3160e_row2_col3, #T_3160e_row3_col1, #T_3160e_row3_col5, #T_3160e_row3_col19, #T_3160e_row4_col5, #T_3160e_row4_col16, #T_3160e_row5_col3, #T_3160e_row5_col4, #T_3160e_row5_col8, #T_3160e_row6_col9, #T_3160e_row6_col13, #T_3160e_row6_col16, #T_3160e_row7_col10, #T_3160e_row7_col11, #T_3160e_row7_col16, #T_3160e_row8_col5, #T_3160e_row8_col9, #T_3160e_row8_col19, #T_3160e_row9_col3, #T_3160e_row9_col4, #T_3160e_row9_col17, #T_3160e_row10_col8, #T_3160e_row11_col2, #T_3160e_row11_col18, #T_3160e_row12_col8, #T_3160e_row12_col14, #T_3160e_row12_col18 {
#   background-color: yellow;
# }
# </style>
# <table id="T_3160e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3160e_level0_col0" class="col_heading level0 col0" >student_id</th>
#       <th id="T_3160e_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_3160e_level0_col2" class="col_heading level0 col2" >gender</th>
#       <th id="T_3160e_level0_col3" class="col_heading level0 col3" >course</th>
#       <th id="T_3160e_level0_col4" class="col_heading level0 col4" >year</th>
#       <th id="T_3160e_level0_col5" class="col_heading level0 col5" >daily_study_hours</th>
#       <th id="T_3160e_level0_col6" class="col_heading level0 col6" >daily_sleep_hours</th>
#       <th id="T_3160e_level0_col7" class="col_heading level0 col7" >screen_time_hours</th>
#       <th id="T_3160e_level0_col8" class="col_heading level0 col8" >stress_level</th>
#       <th id="T_3160e_level0_col9" class="col_heading level0 col9" >anxiety_score</th>
#       <th id="T_3160e_level0_col10" class="col_heading level0 col10" >depression_score</th>
#       <th id="T_3160e_level0_col11" class="col_heading level0 col11" >academic_pressure_score</th>
#       <th id="T_3160e_level0_col12" class="col_heading level0 col12" >financial_stress_score</th>
#       <th id="T_3160e_level0_col13" class="col_heading level0 col13" >social_support_score</th>
#       <th id="T_3160e_level0_col14" class="col_heading level0 col14" >physical_activity_hours</th>
#       <th id="T_3160e_level0_col15" class="col_heading level0 col15" >sleep_quality</th>
#       <th id="T_3160e_level0_col16" class="col_heading level0 col16" >attendance_percentage</th>
#       <th id="T_3160e_level0_col17" class="col_heading level0 col17" >cgpa</th>
#       <th id="T_3160e_level0_col18" class="col_heading level0 col18" >internet_quality</th>
#       <th id="T_3160e_level0_col19" class="col_heading level0 col19" >burnout_level</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3160e_level0_row0" class="row_heading level0 row0" >9793</th>
#       <td id="T_3160e_row0_col0" class="data row0 col0" >84169811</td>
#       <td id="T_3160e_row0_col1" class="data row0 col1" >20.000000</td>
#       <td id="T_3160e_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_3160e_row0_col3" class="data row0 col3" >MCA</td>
#       <td id="T_3160e_row0_col4" class="data row0 col4" >2nd</td>
#       <td id="T_3160e_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_3160e_row0_col6" class="data row0 col6" >6.100000</td>
#       <td id="T_3160e_row0_col7" class="data row0 col7" >5.800000</td>
#       <td id="T_3160e_row0_col8" class="data row0 col8" >Low</td>
#       <td id="T_3160e_row0_col9" class="data row0 col9" >7.000000</td>
#       <td id="T_3160e_row0_col10" class="data row0 col10" >5.000000</td>
#       <td id="T_3160e_row0_col11" class="data row0 col11" >8.000000</td>
#       <td id="T_3160e_row0_col12" class="data row0 col12" >8</td>
#       <td id="T_3160e_row0_col13" class="data row0 col13" >3.000000</td>
#       <td id="T_3160e_row0_col14" class="data row0 col14" >1.900000</td>
#       <td id="T_3160e_row0_col15" class="data row0 col15" >Good</td>
#       <td id="T_3160e_row0_col16" class="data row0 col16" >78.300000</td>
#       <td id="T_3160e_row0_col17" class="data row0 col17" >6.270000</td>
#       <td id="T_3160e_row0_col18" class="data row0 col18" >Good</td>
#       <td id="T_3160e_row0_col19" class="data row0 col19" >Low</td>
#     </tr>
#     <tr>
#       <th id="T_3160e_level0_row1" class="row_heading level0 row1" >41574</th>
#       <td id="T_3160e_row1_col0" class="data row1 col0" >43640236</td>
#       <td id="T_3160e_row1_col1" class="data row1 col1" >21.000000</td>
#       <td id="T_3160e_row1_col2" class="data row1 col2" >Other</td>
#       <td id="T_3160e_row1_col3" class="data row1 col3" >BSc</td>
#       <td id="T_3160e_row1_col4" class="data row1 col4" >2nd</td>
#       <td id="T_3160e_row1_col5" class="data row1 col5" >3.800000</td>
#       <td id="T_3160e_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_3160e_row1_col7" class="data row1 col7" >4.600000</td>
#       <td id="T_3160e_row1_col8" class="data row1 col8" >Medium</td>
#       <td id="T_3160e_row1_col9" class="data row1 col9" >3.000000</td>
#       <td id="T_3160e_row1_col10" class="data row1 col10" >8.000000</td>
#       <td id="T_3160e_row1_col11" class="data row1 col11" >9.000000</td>
#       <td id="T_3160e_row1_col12" class="data row1 col12" >9</td>
#       <td id="T_3160e_row1_col13" class="data row1 col13" >1.000000</td>
#       <td id="T_3160e_row1_col14" class="data row1 col14" >0.400000</td>
#       <td id="T_3160e_row1_col15" class="data row1 col15" >Poor</td>
#       <td id="T_3160e_row1_col16" class="data row1 col16" >74.800000</td>
#       <td id="T_3160e_row1_col17" class="data row1 col17" >8.240000</td>
#       <td id="T_3160e_row1_col18" class="data row1 col18" >Poor</td>
#       <td id="T_3160e_row1_col19" class="data row1 col19" >Medium</td>
#     </tr>
#     <tr>
#       <th id="T_3160e_level0_row2" class="row_heading level0 row2" >48031</th>
#       <td id="T_3160e_row2_col0" class="data row2 col0" >51209733</td>
#       <td id="T_3160e_row2_col1" class="data row2 col1" >20.000000</td>
#       <td id="T_3160e_row2_col2" class="data row2 col2" >Other</td>
#       <td id="T_3160e_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_3160e_row2_col4" class="data row2 col4" >1st</td>
#       <td id="T_3160e_row2_col5" class="data row2 col5" >4.400000</td>
#       <td id="T_3160e_row2_col6" class="data row2 col6" >6.800000</td>
#       <td id="T_3160e_row2_col7" class="data row2 col7" >3.400000</td>
#       <td id="T_3160e_row2_col8" class="data row2 col8" >High</td>
#       <td id="T_3160e_row2_col9" class="data row2 col9" >6.000000</td>
#       <td id="T_3160e_row2_col10" class="data row2 col10" >3.000000</td>
#       <td id="T_3160e_row2_col11" class="data row2 col11" >7.000000</td>
#       <td id="T_3160e_row2_col12" class="data row2 col12" >7</td>
#       <td id="T_3160e_row2_col13" class="data row2 col13" >2.000000</td>
#       <td id="T_3160e_row2_col14" class="data row2 col14" >1.900000</td>
#       <td id="T_3160e_row2_col15" class="data row2 col15" >Average</td>
#       <td id="T_3160e_row2_col16" class="data row2 col16" >70.300000</td>
#       <td id="T_3160e_row2_col17" class="data row2 col17" >7.490000</td>
#       <td id="T_3160e_row2_col18" class="data row2 col18" >Good</td>
#       <td id="T_3160e_row2_col19" class="data row2 col19" >High</td>
#     </tr>
#     <tr>
#       <th id="T_3160e_level0_row3" class="row_heading level0 row3" >48492</th>
#       <td id="T_3160e_row3_col0" class="data row3 col0" >33623626</td>
#       <td id="T_3160e_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_3160e_row3_col2" class="data row3 col2" >Female</td>
#       <td id="T_3160e_row3_col3" class="data row3 col3" >MBA</td>
#       <td id="T_3160e_row3_col4" class="data row3 col4" >3rd</td>
#       <td id="T_3160e_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_3160e_row3_col6" class="data row3 col6" >6.700000</td>
#       <td id="T_3160e_row3_col7" class="data row3 col7" >3.600000</td>
#       <td id="T_3160e_row3_col8" class="data row3 col8" >High</td>
#       <td id="T_3160e_row3_col9" class="data row3 col9" >9.000000</td>
#       <td id="T_3160e_row3_col10" class="data row3 col10" >6.000000</td>
#       <td id="T_3160e_row3_col11" class="data row3 col11" >4.000000</td>
#       <td id="T_3160e_

# %% [markdown]
# > Se identificaron 13 filas con valores nulos. Al representar apenas el `0.0086%` del total del conjunto de datos (150,000 registros), se optó por la eliminación por lista (Listwise Deletion) para no introducir sesgos artificiales mediante técnicas de imputación y preservar la integridad de las observaciones reales.

# %%
# A partir de este momento, el DataFrame original no contará con filas nulas.
df.dropna(inplace=True)

# Total de filas
total_filas = len(df)
display(Markdown(f"Total de registros: {total_filas}"))
# Out:
# Total de registros: 150224

# %% [markdown]
# ### 4.2 Valores Duplicados

# %%
# Contar duplicados y mostrar la alerta
duplicados = df.duplicated().sum()
display(Markdown(f"#### ⚠️ Alerta: Se detectaron {duplicados} filas exactamente duplicadas."))

# Eliminar los duplicados (¡manteniendo la primera aparición!)
df = df.drop_duplicates(keep='first')
display(Markdown(f"#### ✅ Limpieza: Ahora tenemos {len(df)} registros únicos."))
# Out:
# #### ⚠️ Alerta: Se detectaron 237 filas exactamente duplicadas.
# #### ✅ Limpieza: Ahora tenemos 149987 registros únicos.

# %% [markdown]
# Tras someter el conjunto de datos __previamente depurado de valores nulos (150,224 registros)__ a una auditoría exhaustiva de redundancia, se detectaron 263 filas exactamente duplicadas en la totalidad de sus 20 columnas (incluyendo el `student_id`).

# %% [markdown]
# ### 4.3 Datos Sospechosos e Inconsistencias Lógicas
#
# A continuación, realizaremos una auditoría forense estructurada de forma jerárquica, yendo desde las anomalías estructurales severas (fallos de sistema que invalidan por completo al individuo) hasta las inconsistencias específicas de formato (que requieren estandarización antes de la fase de visualización).

# %% [markdown]
# #### 4.3.1 Anomalías de Sistema: Colisiones de Identidad y Actualizaciones
#
# En la arquitectura de datos, el `student_id` actúa como una llave primaria. Un error crítico ocurre cuando un mismo identificador aparece múltiples veces con información divergente en las demás variables.
#
# Dado que la naturaleza de este conjunto de datos proviene de encuestas auto-reportadas, la presencia de colisiones de identidad sugiere que el estudiante envió el formulario, notó un error y volvió a enviarlo con correcciones. Bajo esta regla de negocio, **el último registro ingresado se considera la versión definitiva y verídica**.
#
# A continuación, aislaremos estos casos para observar las discrepancias (qué datos cambió el estudiante) y procederemos a conservar únicamente la última actualización, descartando los intentos previos.

# %%
# 1. Encontrar IDs que aparecen más de una vez
# (Como ya borramos duplicados exactos, estos son colisiones garantizadas)
ids_repetidos = df[df.duplicated(subset=['student_id'], keep=False)]

if ids_repetidos.empty:
    display(Markdown("#### ✅ Integridad de Identidad Validada"))
    print("No se encontraron registros contradictorios bajo un mismo ID.")
else:
    display(Markdown(f"#### ⚠️ Alerta de Colisión de Identidad Detectada"))
# Out:
# #### ✅ Integridad de Identidad Validada
# No se encontraron registros contradictorios bajo un mismo ID.

# %% [markdown]
# #### 4.3.2 Imposibilidades Físicas y Solapamiento de Actividades (Multitasking)
#
# Una validación crucial en encuestas de uso del tiempo es verificar los límites físicos inquebrantables del día (24 horas). En este dataset contamos con cuatro variables de tiempo: horas de estudio (`daily_study_hours`), horas de sueño (`daily_sleep_hours`), tiempo en pantallas (`screen_time_hours`) y actividad física (`physical_activity_hours`).
#
# Un análisis superficial sumaría estas cuatro variables de forma lineal. Sin embargo, desde el conocimiento del dominio, sabemos que para un estudiante contemporáneo, **el tiempo de estudio y el tiempo de pantalla pueden ser actividades paralelas** (ej. estudiar programación en un monitor).
#
# Por lo tanto, para auditar verdaderas imposibilidades físicas, calcularemos el **Límite Físico Estricto**, asumiendo un escenario de solapamiento del 100% entre estudio y pantallas. La fórmula será:
# `Límite Estricto = Sueño + Actividad Física + MAX(Estudio, Pantallas)`
#
# Cualquier registro donde este *Límite Estricto* supere las 24 horas representa una imposibilidad biológica y un fallo crítico en la captura del dato.

# %%
# 1. Calcular el tiempo máximo concurrente entre uso de pantallas y estudio
tiempo_digital_maximo = df[['daily_study_hours', 'screen_time_hours']].max(axis=1)

# 2. Calcular el Límite Físico Estricto
df['strict_physical_hours'] = df['daily_sleep_hours'] + df['physical_activity_hours'] + tiempo_digital_maximo

# 3. Aislar a los registros que infringen las leyes de la física (los verdaderos imposibles)
improbables_fisicos = df[df['strict_physical_hours'] > 24]

# 4. Visualizar los hallazgos
display(Markdown(f"##### ⏳ Inconsistencia Temporal Crítica Detectada"))
display(Markdown(f"> Incluso asumiendo que los estudiantes estudian y miran pantallas al mismo tiempo, se identificaron **{len(improbables_fisicos)} estudiantes** cuyas rutinas exceden el límite de 24 horas."))

if not improbables_fisicos.empty:
    def resaltar_exceso(val):
        color = '#ffb3b3' if val > 24 else ''
        return f'background-color: {color}; font-weight: bold;'
    
    columnas_mostrar = ['student_id', 'daily_sleep_hours', 'physical_activity_hours', 'daily_study_hours', 'screen_time_hours', 'strict_physical_hours']
    
    # Mostrar los casos más extremos ordenados por el exceso de tiempo
    display(improbables_fisicos.sort_values(by='strict_physical_hours', ascending=False)[columnas_mostrar].head(10).style.map(resaltar_exceso, subset=['strict_physical_hours']))

# ==============================================================================
# ACCIÓN FORENSE: ETIQUETADO DE CALIDAD DE DATOS
# ==============================================================================

# Marcar los datos viables frente a los imposibles
df['time_consistency'] = 'Valid'
df.loc[df['strict_physical_hours'] > 24, 'time_consistency'] = 'Impossible'

display(Markdown(f"**Tratamiento aplicado:** Se ha creado la etiqueta analítica `time_consistency`. Los registros clasificados como 'Impossible' evidencian datos basura o sesgos severos de auto-reporte que no pueden ser explicados por el solapamiento de actividades."))
# Out:
# ##### ⏳ Inconsistencia Temporal Crítica Detectada
# > Incluso asumiendo que los estudiantes estudian y miran pantallas al mismo tiempo, se identificaron **990 estudiantes** cuyas rutinas exceden el límite de 24 horas.
# <style type="text/css">
# #T_dd6ed_row0_col5, #T_dd6ed_row1_col5, #T_dd6ed_row2_col5, #T_dd6ed_row3_col5, #T_dd6ed_row4_col5, #T_dd6ed_row5_col5, #T_dd6ed_row6_col5, #T_dd6ed_row7_col5, #T_dd6ed_row8_col5, #T_dd6ed_row9_col5 {
#   background-color: #ffb3b3;
#   font-weight: bold;
# }
# </style>
# <table id="T_dd6ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd6ed_level0_col0" class="col_heading level0 col0" >student_id</th>
#       <th id="T_dd6ed_level0_col1" class="col_heading level0 col1" >daily_sleep_hours</th>
#       <th id="T_dd6ed_level0_col2" class="col_heading level0 col2" >physical_activity_hours</th>
#       <th id="T_dd6ed_level0_col3" class="col_heading level0 col3" >daily_study_hours</th>
#       <th id="T_dd6ed_level0_col4" class="col_heading level0 col4" >screen_time_hours</th>
#       <th id="T_dd6ed_level0_col5" class="col_heading level0 col5" >strict_physical_hours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd6ed_level0_row0" class="row_heading level0 row0" >87147</th>
#       <td id="T_dd6ed_row0_col0" class="data row0 col0" >59928368</td>
#       <td id="T_dd6ed_row0_col1" class="data row0 col1" >11.700000</td>
#       <td id="T_dd6ed_row0_col2" class="data row0 col2" >1.600000</td>
#       <td id="T_dd6ed_row0_col3" class="data row0 col3" >27.833084</td>
#       <td id="T_dd6ed_row0_col4" class="data row0 col4" >2.300000</td>
#       <td id="T_dd6ed_row0_col5" class="data row0 col5" >41.133084</td>
#     </tr>
#     <tr>
#       <th id="T_dd6ed_level0_row1" class="row_heading level0 row1" >131754</th>
#       <td id="T_dd6ed_row1_col0" class="data row1 col0" >24400649</td>
#       <td id="T_dd6ed_row1_col1" class="data row1 col1" >11.800000</td>
#       <td id="T_dd6ed_row1_col2" class="data row1 col2" >0.500000</td>
#       <td id="T_dd6ed_row1_col3" class="data row1 col3" >27.859511</td>
#       <td id="T_dd6ed_row1_col4" class="data row1 col4" >3.500000</td>
#       <td id="T_dd6ed_row1_col5" class="data row1 col5" >40.159511</td>
#     </tr>
#     <tr>
#       <th id="T_dd6ed_level0_row2" class="row_heading level0 row2" >91130</th>
#       <td id="T_dd6ed_row2_col0" class="data row2 col0" >12101785</td>
#       <td id="T_dd6ed_row2_col1" class="data row2 col1" >11.100000</td>
#       <td id="T_dd6ed_row2_col2" class="data row2 col2" >1.200000</td>
#       <td id="T_dd6ed_row2_col3" class="data row2 col3" >27.812935</td>
#       <td id="T_dd6ed_row2_col4" class="data row2 col4" >5.700000</td>
#       <td id="T_dd6ed_row2_col5" class="data row2 col5" >40.112935</td>
#     </tr>
#     <tr>
#       <th id="T_dd6ed_level0_row3" class="row_heading level0 row3" >108314</th>
#       <td id="T_dd6ed_row3_col0" class="data row3 col0" >25919072</td>
#       <td id="T_dd6ed_row3_col1" class="data row3 col1" >12.000000</td>
#       <td id="T_dd6ed_row3_col2" class="data row3 col2" >1.900000</td>
#       <td id="T_dd6ed_row3_col3" class="data row3 col3" >25.992554</td>
#       <td id="T_dd6ed_row3_col4" class="data row3 col4" >6.500000</td>
#       <td id="T_dd6ed_row3_col5" class="data row3 col5" >39.892554</td>
#     </tr>
#     <tr>
#       <th id="T_dd6ed_level0_row4" class="row_heading level0 row4" >125652</th>
#       <td id="T_dd6ed_row4_col0" class="data row4 col0" >73863716</td>
#       <td id="T_dd6ed_row4_col1" class="data row4 col1" >11.200000</td>
#       <td id="T_dd6ed_row4_col2" class="data row4 col2" >0.900000</td>
#       <td id="T_dd6ed_row4_col3" class="data row4 col3" >27.428015</td>
#       <td id="T_dd6ed_row4_col4" class="data row4 col4" >4.300000</td>
#       <td id="T_dd6ed_row4_col5" class="data row4 col5" >39.528015</td>
#     </tr>
#     <tr>
#       <th id="T_dd6ed_level0_row5" class="row_heading level0 row5" >74143</th>
#       <td id="T_dd6ed_row5_col0" class="data row5 col0" >75075837</td>
#       <td id="T_dd6ed_row5_col1" class="data row5 col1" >10.800000</td>
#       <td id="T_dd6ed_row5_col2" class="data row5 col2" >1.300000</td>
#       <td id="T_dd6ed_row5_col3" class="data row5 col3" >27.303149</td>
#       <td id="T_dd6ed_row5_col4" class="data row5 col4" >2.400000</td>
#       <td id="T_dd6ed_row5_col5" class="data row5 col5" >39.403149</td>
#     </tr>
#     <tr>
#       <th id="T_dd6ed_level0_row6" class="row_heading level0 row6" >26443</th>
#       <td id="T_dd6ed_row6_col0" class="data row6 col0" >12531602</td>
#       <td id="T_dd6ed_row6_col1" class="data row6 col1" >9.600000</td>
#       <td id="T_dd6ed_row6_col2" class="data row6 col2" >1.700000</td>
#       <td id="T_dd6ed_row6_col3" class="data row6 col3" >27.866011</td>
#       <td id="T_dd6ed_row6_col4" class="data row6 col4" >4.500000</td>
#       <td id="T_dd6ed_row6_col5" class="data row6 col5" >39.166011</td>
#     </tr>
#     <tr>
#       <th id="T_dd6ed_level0_row7" class="row_heading level0 row7" >127070</th>
#       <td id="T_dd6ed_row7_col0" class="data row7 col0" >67030831</td>
#       <td id="T_dd6ed_row7_col1" class="data row7 col1" >11.100000</td>
#       <td id="T_dd6ed_row7_col2" class="data row7 col2" >0.800000</td>
#       <td id="T_dd6ed_row7_col3" class="data row7 col3" >27.261204</td>
#       <td id="T_dd6ed_row7_col4" class="data row7 col4" >7.300000</td>
#       <td id="T_dd6ed_row7_col5" class="data row7 col5" >39.161204</td>
#     </tr>
#     <tr>
#       <th id="T_dd6ed_level0_row8" class="row_heading level0 row8" >137459</th>
#       <td id="T_dd6ed_row8_col0" class="data row8 col0" >11377181</td>
#       <td id="T_dd6ed_row8_col1" class="data row8 col1" >10.800000</td>
#       <td id="T_dd6ed_row8_col2" class="data row8 col2" >1.200000</td>
#       <td id="T_dd6ed_row8_col3" class="data row8 col3" >26.583633</td>
#       <td id="T_dd6ed_row8_col4" class="data row8 col4" >3.400000</td>
#       <td id="T_dd6ed_row8_col5" class="data row8 col5" >38.583633</td>
#     </tr>
#     <tr>
#       <th id="T_dd6ed_level0_row9" class="row_heading level0 row9" >19699</th>
#       <td id="T_dd6ed_row9_col0" class="data row9 col0" >47195891</td>
#       <td id="T_dd6ed_row9_col1" class="data row9 col1" >9.200000</td>
#       <td id="T_dd6ed_row9_col2" class="data row9 col2" >1.600000</td>
#       <td id="T_dd6ed_row9_col3" class="data row9 col3" >27.398362</td>
#       <td id="T_dd6ed_row9_col4" class="data row9 col4" >7.400000</td>
#       <td id="T_dd6ed_row9_col5" class="data row9 col5" >38.198362</td>
#     </tr>
#   </tbody>
# </table>
# **Tratamiento aplicado:** Se ha creado la etiqueta analítica `time_consistency`. Los registros clasificados como 'Impossible' evidencian datos basura o sesgos severos de auto-reporte que no pueden ser explicados por el solapamiento de actividades.

# %% [markdown]
# > **Veredicto y Decisión de Tratamiento:**
# >
# > Detectar registros que violan las leyes de la física (incluso asumiendo multitasking) plantea un dilema analítico. La acción estándar sería la eliminación (Listwise Deletion). Sin embargo, desde una perspectiva de **psicología de datos**, la sobreestimación del tiempo invertido (percibir que se estudia/trabaja más horas de las reales) es un síntoma clásicamente documentado en individuos con altos niveles de ansiedad o Síndrome de Burnout.
# >
# > **Decisión:**
# > > 1. **No se eliminarán** estos registros en la fase actual.
# > > 2. Se utilizará la etiqueta creada (`time_consistency`) durante el Análisis Bivariado para validar la *Hipótesis de Distorsión por Estrés* (es decir, comprobar si el grupo `Impossible` presenta una tasa estadísticamente mayor de Burnout).
# > > 3. De cara a un futuro modelo predictivo, estos valores de tiempo anómalos serán normalizados (escalados a un máximo de 24h) o tratados mediante imputación, pero la "bandera" de exageración se mantendrá como una variable predictora (Feature Engineering).

# %% [markdown]
# #### 4.3.3 Matriz de Coherencia Relacional: Edad vs. Progreso Académico
#
# En la calidad de datos, un valor puede ser estadísticamente normal de forma aislada, pero lógicamente imposible al cruzarlo con otra variable. Al analizar las variables `age` (Edad) y `year` (Año de estudio), debemos aplicar reglas de negocio estrictas basadas en la cronología educativa estándar.
#
# Adaptando nuestra lógica al contexto demográfico real (donde el ingreso universitario a los 15 años es un escenario factible), se definió la siguiente **Matriz de Coherencia Flexible**:
# * `1st` (1er año): Edad mínima = 15 años.
# * `2nd` (2do año): Edad mínima = 16 años.
# * `3rd` (3er año): Edad mínima = 17 años.
# * `4th` (4to año): Edad mínima = 18 años.
#
# Cualquier registro que viole esta escalera cronológica (por ejemplo, un estudiante de 17 años en 4to año) representa una falla inequívoca de integridad relacional (ruido en el auto-reporte o error de sistema) y será intervenido.

# %%
# 1. Definir la matriz con parámetros sumamente flexibles
reglas_edad_minima = {
    '1st': 15,
    '2nd': 16,
    '3rd': 17,
    '4th': 18
}

# 2. En lugar de usar máscaras de Pandas directamente, recolectar los IDs o índices anómalos en una lista
indices_anomalos = []

# Iterar de forma segura
for anio, edad_minima in reglas_edad_minima.items():
    # Filtrar a los que rompen la regla
    filtro = (df['year'] == anio) & (df['age'] < edad_minima)
    # Extraer los índices reales y guardarlos en la lista
    indices_anomalos.extend(df[filtro].index.tolist())

# 3. Aislar los registros defectuosos usando loc
df_precoces = df.loc[indices_anomalos]

# 4. Presentar la evidencia
display(Markdown(f"##### 🎓 Auditoría de Escalafón Académico"))
display(Markdown(f"> Se identificaron **{len(df_precoces)} registros** donde la edad reportada es biológicamente inconsistente con el avance académico."))

if not df_precoces.empty:
    display(Markdown("**Muestra de los registros inconsistentes (Evidencia previa a la imputación):**"))
    columnas_ver = ['student_id', 'age', 'course', 'year', 'cgpa']
    display(df_precoces[columnas_ver].head(10).style.map(lambda x: 'background-color: #ffb3b3', subset=['age', 'year']))


if not df_precoces.empty:
    for anio, edad_minima in reglas_edad_minima.items():
        filtro_anomalia = (df['year'] == anio) & (df['age'] < edad_minima)
        
        if filtro_anomalia.sum() > 0:
            # Calcular el valor mínimo condicional
            nuevo_valor = df[(df['year'] == anio) & (df['age'] >= edad_minima)]['age'].min()
            
            # Imputar los valores quirúrgicamente
            df.loc[filtro_anomalia, 'age'] = nuevo_valor
# Out:
# ##### 🎓 Auditoría de Escalafón Académico
# > Se identificaron **4263 registros** donde la edad reportada es biológicamente inconsistente con el avance académico.
# **Muestra de los registros inconsistentes (Evidencia previa a la imputación):**
# <style type="text/css">
# #T_2dcb3_row0_col1, #T_2dcb3_row0_col3, #T_2dcb3_row1_col1, #T_2dcb3_row1_col3, #T_2dcb3_row2_col1, #T_2dcb3_row2_col3, #T_2dcb3_row3_col1, #T_2dcb3_row3_col3, #T_2dcb3_row4_col1, #T_2dcb3_row4_col3, #T_2dcb3_row5_col1, #T_2dcb3_row5_col3, #T_2dcb3_row6_col1, #T_2dcb3_row6_col3, #T_2dcb3_row7_col1, #T_2dcb3_row7_col3, #T_2dcb3_row8_col1, #T_2dcb3_row8_col3, #T_2dcb3_row9_col1, #T_2dcb3_row9_col3 {
#   background-color: #ffb3b3;
# }
# </style>
# <table id="T_2dcb3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dcb3_level0_col0" class="col_heading level0 col0" >student_id</th>
#       <th id="T_2dcb3_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_2dcb3_level0_col2" class="col_heading level0 col2" >course</th>
#       <th id="T_2dcb3_level0_col3" class="col_heading level0 col3" >year</th>
#       <th id="T_2dcb3_level0_col4" class="col_heading level0 col4" >cgpa</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dcb3_level0_row0" class="row_heading level0 row0" >30</th>
#       <td id="T_2dcb3_row0_col0" class="data row0 col0" >19509121</td>
#       <td id="T_2dcb3_row0_col1" class="data row0 col1" >16.000000</td>
#       <td id="T_2dcb3_row0_col2" class="data row0 col2" >MBA</td>
#       <td id="T_2dcb3_row0_col3" class="data row0 col3" >4th</td>
#       <td id="T_2dcb3_row0_col4" class="data row0 col4" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2dcb3_level0_row1" class="row_heading level0 row1" >46</th>
#       <td id="T_2dcb3_row1_col0" class="data row1 col0" >38173898</td>
#       <td id="T_2dcb3_row1_col1" class="data row1 col1" >17.000000</td>
#       <td id="T_2dcb3_row1_col2" class="data row1 col2" >BCA</td>
#       <td id="T_2dcb3_row1_col3" class="data row1 col3" >4th</td>
#       <td id="T_2dcb3_row1_col4" class="data row1 col4" >7.100000</td>
#     </tr>
#     <tr>
#       <th id="T_2dcb3_level0_row2" class="row_heading level0 row2" >82</th>
#       <td id="T_2dcb3_row2_col0" class="data row2 col0" >60763153</td>
#       <td id="T_2dcb3_row2_col1" class="data row2 col1" >17.000000</td>
#       <td id="T_2dcb3_row2_col2" class="data row2 col2" >BTech</td>
#       <td id="T_2dcb3_row2_col3" class="data row2 col3" >4th</td>
#       <td id="T_2dcb3_row2_col4" class="data row2 col4" >6.580000</td>
#     </tr>
#     <tr>
#       <th id="T_2dcb3_level0_row3" class="row_heading level0 row3" >128</th>
#       <td id="T_2dcb3_row3_col0" class="data row3 col0" >16907909</td>
#       <td id="T_2dcb3_row3_col1" class="data row3 col1" >17.000000</td>
#       <td id="T_2dcb3_row3_col2" class="data row3 col2" >MBA</td>
#       <td id="T_2dcb3_row3_col3" class="data row3 col3" >4th</td>
#       <td id="T_2dcb3_row3_col4" class="data row3 col4" >5.690000</td>
#     </tr>
#     <tr>
#       <th id="T_2dcb3_level0_row4" class="row_heading level0 row4" >164</th>
#       <td id="T_2dcb3_row4_col0" class="data row4 col0" >95770312</td>
#       <td id="T_2dcb3_row4_col1" class="data row4 col1" >17.000000</td>
#       <td id="T_2dcb3_row4_col2" class="data row4 col2" >BBA</td>
#       <td id="T_2dcb3_row4_col3" class="data row4 col3" >4th</td>
#       <td id="T_2dcb3_row4_col4" class="data row4 col4" >7.360000</td>
#     </tr>
#     <tr>
#       <th id="T_2dcb3_level0_row5" class="row_heading level0 row5" >200</th>
#       <td id="T_2dcb3_row5_col0" class="data row5 col0" >83915698</td>
#       <td id="T_2dcb3_row5_col1" class="data row5 col1" >17.000000</td>
#       <td id="T_2dcb3_row5_col2" class="data row5 col2" >MCA</td>
#       <td id="T_2dcb3_row5_col3" class="data row5 col3" >4th</td>
#       <td id="T_2dcb3_row5_col4" class="data row5 col4" >7.830000</td>
#     </tr>
#     <tr>
#       <th id="T_2dcb3_level0_row6" class="row_heading level0 row6" >209</th>
#       <td id="T_2dcb3_row6_col0" class="data row6 col0" >81576582</td>
#       <td id="T_2dcb3_row6_col1" class="data row6 col1" >17.000000</td>
#       <td id="T_2dcb3_row6_col2" class="data row6 col2" >BTech</td>
#       <td id="T_2dcb3_row6_col3" class="data row6 col3" >4th</td>
#       <td id="T_2dcb3_row6_col4" class="data row6 col4" >7.480000</td>
#     </tr>
#     <tr>
#       <th id="T_2dcb3_level0_row7" class="row_heading level0 row7" >244</th>
#       <td id="T_2dcb3_row7_col0" class="data row7 col0" >84680421</td>
#       <td id="T_2dcb3_row7_col1" class="data row7 col1" >17.000000</td>
#       <td id="T_2dcb3_row7_col2" class="data row7 col2" >BTech</td>
#       <td id="T_2dcb3_row7_col3" class="data row7 col3" >4th</td>
#       <td id="T_2dcb3_row7_col4" class="data row7 col4" >6.600000</td>
#     </tr>
#     <tr>
#       <th id="T_2dcb3_level0_row8" class="row_heading level0 row8" >253</th>
#       <td id="T_2dcb3_row8_col0" class="data row8 col0" >73335817</td>
#       <td id="T_2dcb3_row8_col1" class="data row8 col1" >16.000000</td>
#       <td id="T_2dcb3_row8_col2" class="data row8 col2" >B.C.A.</td>
#       <td id="T_2dcb3_row8_col3" class="data row8 col3" >4th</td>
#       <td id="T_2dcb3_row8_col4" class="data row8 col4" >5.440000</td>
#     </tr>
#     <tr>
#       <th id="T_2dcb3_level0_row9" class="row_heading level0 row9" >266</th>
#       <td id="T_2dcb3_row9_col0" class="data row9 col0" >88572190</td>
#       <td id="T_2dcb3_row9_col1" class="data row9 col1" >17.000000</td>
#       <td id="T_2dcb3_row9_col2" class="data row9 col2" >MBA</td>
#       <td id="T_2dcb3_row9_col3" class="data row9 col3" >4th</td>
#       <td id="T_2dcb3_row9_col4" class="data row9 col4" >8.170000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > **Tratamiento aplicado:** Para mantener la política de "Cero Nulos" sin alterar la distribución general, se aplicó un algoritmo de **Imputación Condicional Dinámica**. Los infractores de cada año recibieron la edad mínima exclusiva de sus compañeros de corte que sí cumplían con la regla cronológica. Esto neutraliza el ruido sin castigar la retención de datos vitales para el análisis psicológico.

# %% [markdown]
# ### 4.3.4 Ruido de Rango y Outliers Extremos: Anomalías Demográficas (Edad)
#
# Una vez resueltas las inconsistencias lógicas cruzadas y las imposibilidades físicas de tiempo, nos enfocamos en el ruido de rango de variables individuales. En este caso, la variable `age` (edad).
#
# En el contexto universitario general, las edades tienen una distribución asimétrica positiva muy marcada: la inmensa mayoría se concentra entre los 18 y los 25 años, con una cola larga hacia la derecha (estudiantes de posgrado o adultos retomando estudios). Sin embargo, la presencia de edades correspondientes a la tercera edad (ej. > 60, 80 o 90 años) rompe el sentido común demográfico para este conjunto de datos.
#
# Estos valores no representan la variabilidad natural de la población, sino "ruido" puro (errores tipográficos durante la captura de datos, como digitar "85" en lugar de "18" o "25"). Dejarlos intactos deformaría la media, arruinaría las visualizaciones univariadas y sesgaría cualquier modelo de machine learning posterior.
#
# A continuación, exponemos la gravedad de estos valores atípicos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Resumen estadístico de la edad para ver el máximo disparatado
print("Resumen estadístico de la variable 'age':")
display(df[['age']].describe().T)

# 2. Visualización del problema: Boxplot + Histograma
fig, (ax_box, ax_hist) = plt.subplots(2, 1, sharex=True, figsize=(12, 6), gridspec_kw={"height_ratios": (.15, .85)})
sns.set_style("whitegrid")

# Boxplot arriba (para detectar los puntos atípicos)
sns.boxplot(x=df['age'], ax=ax_box, color='#FC9C28') # Naranja UAL
ax_box.set(xlabel='')
ax_box.set_title('Distribución de la Edad y Outliers Extremos', fontsize=14)

# Histograma abajo (para ver la concentración real vs el ruido)
sns.histplot(df['age'], bins=30, kde=False, ax=ax_hist, color='#BA352C') # Rojo UAL
ax_hist.set(xlabel='Edad (Años)', ylabel='Cantidad de Estudiantes')

plt.tight_layout()
plt.show()

# 3. Filtrar y exhibir a los "ancianos universitarios"
umbral_edad_extrema = 70 # Ajustable según tu criterio
df_edades_absurdas = df[df['age'] > umbral_edad_extrema]

print(f"\nTotal de estudiantes con edades irreales (> {umbral_edad_extrema} años): {len(df_edades_absurdas)}")
display(df_edades_absurdas[['student_id', 'age', 'course', 'year', 'burnout_level']].head(10))
# Out:
# Resumen estadístico de la variable 'age':
#         count       mean       std   min   25%   50%   75%   max
# age  149987.0  21.284045  4.453859  17.0  19.0  21.0  23.0  98.0
# Total de estudiantes con edades irreales (> 70 años): 374
#       student_id   age course year burnout_level
# 494     40759886  98.0    BBA  4th        Medium
# 534     27998486  89.0  BTech  1st          High
# 620     53358095  87.0  BTech  1st          High
# 715     86623369  90.0    MBA  3rd        Medium
# 1081    81144384  94.0    BSc  2nd           Low
# 1279    96680769  85.0    BBA  1st          High
# 1564    77348817  88.0    BBA  3rd           Low
# 2470    21589049  81.0  BTech  4th           Low
# 2479    78126133  76.0    MBA  2nd        Medium
# 2864    45149770  93.0    BCA  1st           Low

# %% [markdown]
# > **Tratamiento aplicado:** Para aislar las anomalías demográficas sin recurrir a la eliminación destructiva, se implementó una estrategia de etiquetado (*Flagging*) basada en un método paramétrico estándar. Se definió el límite de normalidad superior utilizando la fórmula de la media poblacional más $5$ veces la desviación estándar ($\mu + 5\sigma$). Todo registro que superó este umbral recibió la etiqueta `'Suspicious'` en una nueva variable de control (`is_age_suspicious`).
# >
# > **Justificación del Negocio:** La edad universitaria suele tener una distribución asimétrica con una cola larga hacia la derecha. Al fijar el límite en 5 desviaciones estándar por encima de la media, garantizamos la protección de los estudiantes "fuera de la edad tradicional" (adultos, posgrados o reingresos), asegurando que la bandera de error señale única y exclusivamente a valores demográficos físicamente inverosímiles (errores de captura en el sistema).

# %%
# 1. Calcular la Media poblacional y la Desviación Estándar para 'age'
edad_media = df['age'].mean()
edad_std = df['age'].std()

# 2. Calcular el umbral estadístico superior (Media + 5 Desviaciones Estándar)
# Mantenemos el multiplicador en 5 para ser extremadamente conservadores
umbral_superior = edad_media + (5 * edad_std)

# 3. Etiquetar los registros que superen el umbral en una nueva columna de control (flag)
df['is_age_suspicious'] = np.where(df['age'] > umbral_superior, 'Suspicious', 'Normal')

# 4. Verificar el resultado
print(f"El umbral superior estadístico calculado es: {umbral_superior:.2f} años\n")

# Mostrar una muestra de los infractores
df_sospechosos = df[df['is_age_suspicious'] == 'Suspicious']
print(f"Total de registros marcados como sospechosos: {len(df_sospechosos)}")
display(df_sospechosos[['student_id', 'age', 'course', 'year', 'is_age_suspicious']].head(10))
# Out:
# El umbral superior estadístico calculado es: 43.55 años
#
# Total de registros marcados como sospechosos: 709
#       student_id   age course year is_age_suspicious
# 494     40759886  98.0    BBA  4th        Suspicious
# 534     27998486  89.0  BTech  1st        Suspicious
# 596     11503688  44.0    BSc  4th        Suspicious
# 620     53358095  87.0  BTech  1st        Suspicious
# 715     86623369  90.0    MBA  3rd        Suspicious
# 1081    81144384  94.0    BSc  2nd        Suspicious
# 1279    96680769  85.0    BBA  1st        Suspicious
# 1564    77348817  88.0    BBA  3rd        Suspicious
# 2470    21589049  81.0  BTech  4th        Suspicious
# 2479    78126133  76.0    MBA  2nd        Suspicious

# %% [markdown]
# ### 4.3.5 Inconsistencias Categóricas (Falta de Estandarización)
#
# Las variables cualitativas (texto) son altamente susceptibles a errores de formato, especialmente si provienen de captura manual o de la consolidación de múltiples sistemas. Las variaciones de mayúsculas/minúsculas y los espacios en blanco invisibles (trailing/leading spaces) generan una fragmentación artificial de las categorías.
#
# Si no se estandariza el texto, el motor analítico tratará variaciones semánticamente idénticas (ej. `'Male'` y `'Male '`) como entidades distintas. Esto arruinaría la integridad de los conteos y la posterior visualización univariada.
#
# A continuación, ejecutamos una auditoría de distribución de frecuencias sobre todas las variables categóricas. Esto nos permite identificar no solo la presencia de ruido tipográfico, sino también el peso porcentual de cada inconsistencia dentro del conjunto de datos.

# %%
# 1. Identificar automáticamente las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['object', 'str']).columns

print("--- AUDITORÍA DE CATEGORÍAS (VISTA PIVOTEADA) ---\n")

for col in columnas_categoricas:
    # 2. Calcular Frecuencias y Porcentajes
    frec = df[col].value_counts(dropna=False)
    porc = df[col].value_counts(dropna=False, normalize=True) * 100
    
    # 3. Visibilizar espacios en blanco envolviendo los nombres en comillas
    nombres_columnas = [f"'{x}'" if pd.notnull(x) else 'NaN' for x in frec.index]
    
    # 4. Construir la tabla pivoteada (2 filas, N columnas)
    tabla = pd.DataFrame(
        [frec.values, porc.values],
        index=['Frecuencia', 'Porcentaje'],
        columns=nombres_columnas
    )
    
    # 5. Aplicar estilos avanzados por filas usando pd.IndexSlice
    estilo_tabla = (tabla.style
        # Formato de números: enteros para la fila 1, porcentajes para la fila 2
        .format("{:.0f}", subset=pd.IndexSlice['Frecuencia', :])
        .format("{:.2f}%", subset=pd.IndexSlice['Porcentaje', :])
        # Aplicar la barra SOLO a la fila de porcentaje. axis=1 le dice a Pandas que lo haga horizontalmente
        .bar(subset=pd.IndexSlice['Porcentaje', :], axis=1, color='rgba(252, 156, 40, 0.3)', vmin=0, vmax=100)
        # Título con el color exacto solicitado
        .set_caption(f"Distribución en: {col}")
        .set_table_styles([{
            'selector': 'caption',
            'props': [('font-size', '15px'), ('color', '#BA352C'), ('font-weight', 'bold'), ('text-align', 'left'), ('margin-bottom', '8px')]
        },
        {   # Para darle un poco de estilo al nombre de las filas (Frecuencia / Porcentaje)
            'selector': 'th.row_heading',
            'props': [('font-weight', 'bold')]
        }])
    )
    
    # 6. Desplegar la tabla
    display(estilo_tabla)
    print("\n")
# Out:
# --- AUDITORÍA DE CATEGORÍAS (VISTA PIVOTEADA) ---
# <style type="text/css">
# #T_b6fa1 caption {
#   font-size: 15px;
#   color: #BA352C;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 8px;
# }
# #T_b6fa1 th.row_heading {
#   font-weight: bold;
# }
# #T_b6fa1_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.4%, transparent 33.4%);
# }
# #T_b6fa1_row1_col1, #T_b6fa1_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 32.3%, transparent 32.3%);
# }
# #T_b6fa1_row1_col3, #T_b6fa1_row1_col4, #T_b6fa1_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 0.4%, transparent 0.4%);
# }
# #T_b6fa1_row1_col6, #T_b6fa1_row1_col7, #T_b6fa1_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 0.3%, transparent 0.3%);
# }
# </style>
# <table id="T_b6fa1">
#   <caption>Distribución en: gender</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6fa1_level0_col0" class="col_heading level0 col0" >'Other'</th>
#       <th id="T_b6fa1_level0_col1" class="col_heading level0 col1" >'Female'</th>
#       <th id="T_b6fa1_level0_col2" class="col_heading level0 col2" >'Male'</th>
#       <th id="T_b6fa1_level0_col3" class="col_heading level0 col3" >'  Male'</th>
#       <th id="T_b6fa1_level0_col4" class="col_heading level0 col4" >'FEMALE'</th>
#       <th id="T_b6fa1_level0_col5" class="col_heading level0 col5" >'female'</th>
#       <th id="T_b6fa1_level0_col6" class="col_heading level0 col6" >'male'</th>
#       <th id="T_b6fa1_level0_col7" class="col_heading level0 col7" >'Femal'</th>
#       <th id="T_b6fa1_level0_col8" class="col_heading level0 col8" >'MALE'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6fa1_level0_row0" class="row_heading level0 row0" >Frecuencia</th>
#       <td id="T_b6fa1_row0_col0" class="data row0 col0" >50043</td>
#       <td id="T_b6fa1_row0_col1" class="data row0 col1" >48404</td>
#       <td id="T_b6fa1_row0_col2" class="data row0 col2" >48386</td>
#       <td id="T_b6fa1_row0_col3" class="data row0 col3" >542</td>
#       <td id="T_b6fa1_row0_col4" class="data row0 col4" >532</td>
#       <td id="T_b6fa1_row0_col5" class="data row0 col5" >528</td>
#       <td id="T_b6fa1_row0_col6" class="data row0 col6" >522</td>
#       <td id="T_b6fa1_row0_col7" class="data row0 col7" >517</td>
#       <td id="T_b6fa1_row0_col8" class="data row0 col8" >513</td>
#     </tr>
#     <tr>
#       <th id="T_b6fa1_level0_row1" class="row_heading level0 row1" >Porcentaje</th>
#       <td id="T_b6fa1_row1_col0" class="data row1 col0" >33.36%</td>
#       <td id="T_b6fa1_row1_col1" class="data row1 col1" >32.27%</td>
#       <td id="T_b6fa1_row1_col2" class="data row1 col2" >32.26%</td>
#       <td id="T_b6fa1_row1_col3" class="data row1 col3" >0.36%</td>
#       <td id="T_b6fa1_row1_col4" class="data row1 col4" >0.35%</td>
#       <td id="T_b6fa1_row1_col5" class="data row1 col5" >0.35%</td>
#       <td id="T_b6fa1_row1_col6" class="data row1 col6" >0.35%</td>
#       <td id="T_b6fa1_row1_col7" class="data row1 col7" >0.34%</td>
#       <td id="T_b6fa1_row1_col8" class="data row1 col8" >0.34%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7c631 caption {
#   font-size: 15px;
#   color: #BA352C;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 8px;
# }
# #T_7c631 th.row_heading {
#   font-weight: bold;
# }
# #T_7c631_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 16.7%, transparent 16.7%);
# }
# #T_7c631_row1_col1, #T_7c631_row1_col2, #T_7c631_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 16.6%, transparent 16.6%);
# }
# #T_7c631_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 16.4%, transparent 16.4%);
# }
# #T_7c631_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 16.3%, transparent 16.3%);
# }
# #T_7c631_row1_col6, #T_7c631_row1_col7, #T_7c631_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 0.2%, transparent 0.2%);
# }
# </style>
# <table id="T_7c631">
#   <caption>Distribución en: course</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c631_level0_col0" class="col_heading level0 col0" >'BBA'</th>
#       <th id="T_7c631_level0_col1" class="col_heading level0 col1" >'MCA'</th>
#       <th id="T_7c631_level0_col2" class="col_heading level0 col2" >'BSc'</th>
#       <th id="T_7c631_level0_col3" class="col_heading level0 col3" >'MBA'</th>
#       <th id="T_7c631_level0_col4" class="col_heading level0 col4" >'BCA'</th>
#       <th id="T_7c631_level0_col5" class="col_heading level0 col5" >'BTech'</th>
#       <th id="T_7c631_level0_col6" class="col_heading level0 col6" >'M.B.A'</th>
#       <th id="T_7c631_level0_col7" class="col_heading level0 col7" >'B.C.A.'</th>
#       <th id="T_7c631_level0_col8" class="col_heading level0 col8" >'B-Tech'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c631_level0_row0" class="row_heading level0 row0" >Frecuencia</th>
#       <td id="T_7c631_row0_col0" class="data row0 col0" >25100</td>
#       <td id="T_7c631_row0_col1" class="data row0 col1" >24946</td>
#       <td id="T_7c631_row0_col2" class="data row0 col2" >24892</td>
#       <td id="T_7c631_row0_col3" class="data row0 col3" >24879</td>
#       <td id="T_7c631_row0_col4" class="data row0 col4" >24627</td>
#       <td id="T_7c631_row0_col5" class="data row0 col5" >24503</td>
#       <td id="T_7c631_row0_col6" class="data row0 col6" >350</td>
#       <td id="T_7c631_row0_col7" class="data row0 col7" >346</td>
#       <td id="T_7c631_row0_col8" class="data row0 col8" >344</td>
#     </tr>
#     <tr>
#       <th id="T_7c631_level0_row1" class="row_heading level0 row1" >Porcentaje</th>
#       <td id="T_7c631_row1_col0" class="data row1 col0" >16.73%</td>
#       <td id="T_7c631_row1_col1" class="data row1 col1" >16.63%</td>
#       <td id="T_7c631_row1_col2" class="data row1 col2" >16.60%</td>
#       <td id="T_7c631_row1_col3" class="data row1 col3" >16.59%</td>
#       <td id="T_7c631_row1_col4" class="data row1 col4" >16.42%</td>
#       <td id="T_7c631_row1_col5" class="data row1 col5" >16.34%</td>
#       <td id="T_7c631_row1_col6" class="data row1 col6" >0.23%</td>
#       <td id="T_7c631_row1_col7" class="data row1 col7" >0.23%</td>
#       <td id="T_7c631_row1_col8" class="data row1 col8" >0.23%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d4a8f caption {
#   font-size: 15px;
#   color: #BA352C;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 8px;
# }
# #T_d4a8f th.row_heading {
#   font-weight: bold;
# }
# #T_d4a8f_row1_col0, #T_d4a8f_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 25.1%, transparent 25.1%);
# }
# #T_d4a8f_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 24.9%, transparent 24.9%);
# }
# #T_d4a8f_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 24.8%, transparent 24.8%);
# }
# </style>
# <table id="T_d4a8f">
#   <caption>Distribución en: year</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4a8f_level0_col0" class="col_heading level0 col0" >'1st'</th>
#       <th id="T_d4a8f_level0_col1" class="col_heading level0 col1" >'4th'</th>
#       <th id="T_d4a8f_level0_col2" class="col_heading level0 col2" >'3rd'</th>
#       <th id="T_d4a8f_level0_col3" class="col_heading level0 col3" >'2nd'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4a8f_level0_row0" class="row_heading level0 row0" >Frecuencia</th>
#       <td id="T_d4a8f_row0_col0" class="data row0 col0" >37678</td>
#       <td id="T_d4a8f_row0_col1" class="data row0 col1" >37619</td>
#       <td id="T_d4a8f_row0_col2" class="data row0 col2" >37419</td>
#       <td id="T_d4a8f_row0_col3" class="data row0 col3" >37271</td>
#     </tr>
#     <tr>
#       <th id="T_d4a8f_level0_row1" class="row_heading level0 row1" >Porcentaje</th>
#       <td id="T_d4a8f_row1_col0" class="data row1 col0" >25.12%</td>
#       <td id="T_d4a8f_row1_col1" class="data row1 col1" >25.08%</td>
#       <td id="T_d4a8f_row1_col2" class="data row1 col2" >24.95%</td>
#       <td id="T_d4a8f_row1_col3" class="data row1 col3" >24.85%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b1770 caption {
#   font-size: 15px;
#   color: #BA352C;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 8px;
# }
# #T_b1770 th.row_heading {
#   font-weight: bold;
# }
# #T_b1770_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.5%, transparent 33.5%);
# }
# #T_b1770_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.4%, transparent 33.4%);
# }
# #T_b1770_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.1%, transparent 33.1%);
# }
# </style>
# <table id="T_b1770">
#   <caption>Distribución en: stress_level</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1770_level0_col0" class="col_heading level0 col0" >'High'</th>
#       <th id="T_b1770_level0_col1" class="col_heading level0 col1" >'Medium'</th>
#       <th id="T_b1770_level0_col2" class="col_heading level0 col2" >'Low'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1770_level0_row0" class="row_heading level0 row0" >Frecuencia</th>
#       <td id="T_b1770_row0_col0" class="data row0 col0" >50290</td>
#       <td id="T_b1770_row0_col1" class="data row0 col1" >50086</td>
#       <td id="T_b1770_row0_col2" class="data row0 col2" >49611</td>
#     </tr>
#     <tr>
#       <th id="T_b1770_level0_row1" class="row_heading level0 row1" >Porcentaje</th>
#       <td id="T_b1770_row1_col0" class="data row1 col0" >33.53%</td>
#       <td id="T_b1770_row1_col1" class="data row1 col1" >33.39%</td>
#       <td id="T_b1770_row1_col2" class="data row1 col2" >33.08%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_28154 caption {
#   font-size: 15px;
#   color: #BA352C;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 8px;
# }
# #T_28154 th.row_heading {
#   font-weight: bold;
# }
# #T_28154_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.4%, transparent 33.4%);
# }
# #T_28154_row1_col1, #T_28154_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.3%, transparent 33.3%);
# }
# </style>
# <table id="T_28154">
#   <caption>Distribución en: sleep_quality</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28154_level0_col0" class="col_heading level0 col0" >'Good'</th>
#       <th id="T_28154_level0_col1" class="col_heading level0 col1" >'Average'</th>
#       <th id="T_28154_level0_col2" class="col_heading level0 col2" >'Poor'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28154_level0_row0" class="row_heading level0 row0" >Frecuencia</th>
#       <td id="T_28154_row0_col0" class="data row0 col0" >50141</td>
#       <td id="T_28154_row0_col1" class="data row0 col1" >49971</td>
#       <td id="T_28154_row0_col2" class="data row0 col2" >49875</td>
#     </tr>
#     <tr>
#       <th id="T_28154_level0_row1" class="row_heading level0 row1" >Porcentaje</th>
#       <td id="T_28154_row1_col0" class="data row1 col0" >33.43%</td>
#       <td id="T_28154_row1_col1" class="data row1 col1" >33.32%</td>
#       <td id="T_28154_row1_col2" class="data row1 col2" >33.25%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_17c9a caption {
#   font-size: 15px;
#   color: #BA352C;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 8px;
# }
# #T_17c9a th.row_heading {
#   font-weight: bold;
# }
# #T_17c9a_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.4%, transparent 33.4%);
# }
# #T_17c9a_row1_col1, #T_17c9a_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.3%, transparent 33.3%);
# }
# </style>
# <table id="T_17c9a">
#   <caption>Distribución en: internet_quality</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17c9a_level0_col0" class="col_heading level0 col0" >'Average'</th>
#       <th id="T_17c9a_level0_col1" class="col_heading level0 col1" >'Poor'</th>
#       <th id="T_17c9a_level0_col2" class="col_heading level0 col2" >'Good'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17c9a_level0_row0" class="row_heading level0 row0" >Frecuencia</th>
#       <td id="T_17c9a_row0_col0" class="data row0 col0" >50132</td>
#       <td id="T_17c9a_row0_col1" class="data row0 col1" >49984</td>
#       <td id="T_17c9a_row0_col2" class="data row0 col2" >49871</td>
#     </tr>
#     <tr>
#       <th id="T_17c9a_level0_row1" class="row_heading level0 row1" >Porcentaje</th>
#       <td id="T_17c9a_row1_col0" class="data row1 col0" >33.42%</td>
#       <td id="T_17c9a_row1_col1" class="data row1 col1" >33.33%</td>
#       <td id="T_17c9a_row1_col2" class="data row1 col2" >33.25%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b3205 caption {
#   font-size: 15px;
#   color: #BA352C;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 8px;
# }
# #T_b3205 th.row_heading {
#   font-weight: bold;
# }
# #T_b3205_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.5%, transparent 33.5%);
# }
# #T_b3205_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.3%, transparent 33.3%);
# }
# #T_b3205_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 33.2%, transparent 33.2%);
# }
# </style>
# <table id="T_b3205">
#   <caption>Distribución en: burnout_level</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3205_level0_col0" class="col_heading level0 col0" >'Low'</th>
#       <th id="T_b3205_level0_col1" class="col_heading level0 col1" >'Medium'</th>
#       <th id="T_b3205_level0_col2" class="col_heading level0 col2" >'High'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3205_level0_row0" class="row_heading level0 row0" >Frecuencia</th>
#       <td id="T_b3205_row0_col0" class="data row0 col0" >50261</td>
#       <td id="T_b3205_row0_col1" class="data row0 col1" >49967</td>
#       <td id="T_b3205_row0_col2" class="data row0 col2" >49759</td>
#     </tr>
#     <tr>
#       <th id="T_b3205_level0_row1" class="row_heading level0 row1" >Porcentaje</th>
#       <td id="T_b3205_row1_col0" class="data row1 col0" >33.51%</td>
#       <td id="T_b3205_row1_col1" class="data row1 col1" >33.31%</td>
#       <td id="T_b3205_row1_col2" class="data row1 col2" >33.18%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_910b6 caption {
#   font-size: 15px;
#   color: #BA352C;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 8px;
# }
# #T_910b6 th.row_heading {
#   font-weight: bold;
# }
# #T_910b6_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 99.3%, transparent 99.3%);
# }
# #T_910b6_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 0.7%, transparent 0.7%);
# }
# </style>
# <table id="T_910b6">
#   <caption>Distribución en: time_consistency</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_910b6_level0_col0" class="col_heading level0 col0" >'Valid'</th>
#       <th id="T_910b6_level0_col1" class="col_heading level0 col1" >'Impossible'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_910b6_level0_row0" class="row_heading level0 row0" >Frecuencia</th>
#       <td id="T_910b6_row0_col0" class="data row0 col0" >148997</td>
#       <td id="T_910b6_row0_col1" class="data row0 col1" >990</td>
#     </tr>
#     <tr>
#       <th id="T_910b6_level0_row1" class="row_heading level0 row1" >Porcentaje</th>
#       <td id="T_910b6_row1_col0" class="data row1 col0" >99.34%</td>
#       <td id="T_910b6_row1_col1" class="data row1 col1" >0.66%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3a158 caption {
#   font-size: 15px;
#   color: #BA352C;
#   font-weight: bold;
#   text-align: left;
#   margin-bottom: 8px;
# }
# #T_3a158 th.row_heading {
#   font-weight: bold;
# }
# #T_3a158_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 99.5%, transparent 99.5%);
# }
# #T_3a158_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, rgba(252, 156, 40, 0.3) 0.5%, transparent 0.5%);
# }
# </style>
# <table id="T_3a158">
#   <caption>Distribución en: is_age_suspicious</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a158_level0_col0" class="col_heading level0 col0" >'Normal'</th>
#       <th id="T_3a158_level0_col1" class="col_heading level0 col1" >'Suspicious'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a158_level0_row0" class="row_heading level0 row0" >Frecuencia</th>
#       <td id="T_3a158_row0_col0" class="data row0 col0" >149278</td>
#       <td id="T_3a158_row0_col1" class="data row0 col1" >709</td>
#     </tr>
#     <tr>
#       <th id="T_3a158_level0_row1" class="row_heading level0 row1" >Porcentaje</th>
#       <td id="T_3a158_row1_col0" class="data row1 col0" >99.53%</td>
#       <td id="T_3a158_row1_col1" class="data row1 col1" >0.47%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > **Tratamiento a aplicar:** Se implementó una rutina de limpieza vectorizada y condicional sobre todas las variables categóricas. El proceso constó de tres pasos en un solo ciclo: (1) Eliminación de espacios residuales (`strip`) en todas las columnas. (2) Para la variable `course`, se aplicó una homogenización a mayúsculas seguida de un mapeo por diccionario para restaurar y proteger la nomenclatura académica estandarizada (ej. `BTech`, `BSc`). (3) Para el resto de variables cualitativas, se forzó un formato de título (`Title Case`) para colapsar variaciones de captura (ej. `"MALE"`, `"male"` $\rightarrow$ `"Male"`).
# >
# > **Justificación del Negocio:** La consolidación de categorías es el prerrequisito innegociable del análisis univariado. Si no se colapsan los errores tipográficos, el motor analítico fragmentará artificialmente a la población, arruinando los conteos de frecuencia y diluyendo la representatividad estadística de variables críticas como los niveles de burnout, estrés o calidad de sueño.

# %%
# 1. Identificar todas las columnas categóricas (compatibilidad Pandas 2/3)
columnas_categoricas = df.select_dtypes(include=['object', 'str']).columns

# 2. Diccionario de mapeo estricto para las nomenclaturas académicas de la variable 'course'
# (Aseguramos las carreras principales que vimos en la auditoría)
mapeo_carreras = {
    'BTECH': 'BTech',
    'B-TECH': 'BTech',
    'MTECH': 'MTech',
    'BSC': 'BSc',
    'MSC': 'MSc',
    'BCA': 'BCA',
    'B.C.A.': 'BCA',
    'MCA': 'MCA',
    'BBA': 'BBA',
    'M.B.A': 'MBA',
    'OTHER': 'Other'
}

# 3. Aplicar limpieza vectorizada en un solo paso
for col in columnas_categoricas:
    # A. Aniquilar espacios invisibles al inicio y final en absolutamente todas las columnas
    df[col] = df[col].str.strip()
    
    # B. Tratamiento condicional según el dominio de la variable
    if col == 'course':
        # Estandarizar temporalmente todo a mayúsculas para evitar fugas por minúsculas rebeldes
        df[col] = df[col].str.upper()
        # Aplicar el reemplazo quirúrgico para recuperar la estética académica
        df[col] = df[col].replace(mapeo_carreras)
    else:
        # Formato de título estándar para variables regulares (Gender, Stress Level, etc.)
        df[col] = df[col].str.title()

# 4. Verificación final de integridad (Auditoría post-limpieza)
print("--- RESULTADO DE LA ESTANDARIZACIÓN GLOBAL ---\n")
for col in columnas_categoricas:
    valores_limpios = df[col].dropna().unique()
    print(f"✅ '{col}' ({len(valores_limpios)} categorías): {list(valores_limpios)}")
# Out:
# --- RESULTADO DE LA ESTANDARIZACIÓN GLOBAL ---
#
# ✅ 'gender' (4 categorías): ['Male', 'Female', 'Other', 'Femal']
# ✅ 'course' (6 categorías): ['BTech', 'BCA', 'BSc', 'MBA', 'MCA', 'BBA']
# ✅ 'year' (4 categorías): ['1St', '3Rd', '4Th', '2Nd']
# ✅ 'stress_level' (3 categorías): ['High', 'Low', 'Medium']
# ✅ 'sleep_quality' (3 categorías): ['Average', 'Poor', 'Good']
# ✅ 'internet_quality' (3 categorías): ['Good', 'Poor', 'Average']
# ✅ 'burnout_level' (3 categorías): ['High', 'Low', 'Medium']
# ✅ 'time_consistency' (2 categorías): ['Valid', 'Impossible']
# ✅ 'is_age_suspicious' (2 categorías): ['Normal', 'Suspicious']
