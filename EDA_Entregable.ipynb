# %% [markdown]
# Medellín, Colombia 24 de Abril de 2026
# <table style="border: none; border-collapse: collapse;">
#     <tr style="border: none;">
#         <td style="border: none;">
#             <img src="https://github.com/kevinmateojimenez/TRABAJO-FINAL/blob/main/img/logo.png" style="width: 100px;"/>
#         </td>
#         <td style="border: none;">
#             <span style="color:#BA352C;">Universidad Autónoma Latinoamericana</span> </br>
#             <span style="color:#FC9C28;">Especialización, Analítica de datos - Grupo 2</span>
#         </td>
#     </tr>
# </table>
#
# <span style="font-size: 24px;"> Entregable Final de la Asignatura: Principios analíticos para la ciencia de datos </span>
#
# |Estudiante|ID Institucional|
# |:-|-:|
# |Evelin Dahiana Franco Campiño|evelin.franco9635|
# |Nicolle Gaviria Mejía| nicolle.gaviria3451|
# |Kevin Mate Jiménez Guisao|kevin.jimenez3582|
#
# </br>
#
# ***

# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
# ## Salud mental estudiantil y síndrome de burnout
#
# ### 📄Introducción
#
# <p>
#     El Conjunto de Datos sobre Salud Mental y Agotamiento Estudiantil (150k filas, 20 características) es una base de datos a gran escala diseñada para analizar y predecir los niveles de burnout (agotamiento) estudiantil basándose en factores académicos, psicológicos y de estilo de vida.
# </p>
#
#     Este conjunto de datos contiene 150,000 registros de estudiantes con una combinación de variables numéricas y categóricas, lo que lo hace ideal para tareas de aprendizaje automático (machine learning), clasificación y análisis de datos.

# %% [markdown]
# ### 🧮Conjunto de Datos
# **Caracteristicas:**
# - Demografía: Edad, género, carrera y año académico.
#
# - Indicadores académicos: Promedio general (CGPA), asistencia y horas de estudio.
#
# - Puntajes psicológicos: Niveles de ansiedad, depresión y estrés.
#
# - Factores de estilo de vida: Horas de sueño, actividad física y tiempo frente a la pantalla.
#
# - Indicadores de estrés social y financiero.
#
# - Variable objetivo: `burnout_level` (nivel de agotamiento).

# %% [markdown]
# <table>
#     <thead>
#         <tr style="background-color: #BA352C80;">
#             <td>
#                 <b>Información</b>
#             </td>
#             <td>
#                 <b>Detalle</b>
#             </td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="background-color: #FC9C2880">
#                 Fuente
#             </td>
#             <td>
#                 <a href="https://www.kaggle.com/datasets/sehaj1104/student-mental-health-and-burnout-dataset/data">kaggle.com</a>
#             </td>
#         </tr>
#         <tr>
#             <td style="background-color: #FC9C2880">
#                 Nombre del conjunto de datos
#             </td>
#             <td>
#                 Student Mental Health and Burnout Dataset
#             </td>
#         </tr>
#         <tr>
#             <td style="background-color: #FC9C2880">
#                 Propietario
#             </td>
#             <td>
#                 Mansehaj Preet
#             </td>
#         </tr>
#         <tr>
#             <td style="background-color: #FC9C2880">
#                 Tipo de Origen
#             </td>
#             <td>
#                 Archivo CSV
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# #### Importacion de datos

# %%
import pandas as pd
import numpy as np

path = "data/datos.csv"

# %% [markdown]
# ### 📙Dicionario de Datos
#
# <table>
#     <thead style="background-color: #352cba80">
#         <tr>
#             <td>
#                 <b>Columna</b>
#             </td>
#             <td>
#                 <b>Formato</b>
#             </td>
#             <td>
#                 <b>Descripcion</b>
#             </td>
#             <td>
#                 <b>Ejemplos</b>
#             </td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <b>Columna</b>
#             </td>
#             <td>
#                 <b>Formato</b>
#             </td>
#             <td>
#                 <b>Descripcion</b>
#             </td>
#             <td>
#                 <b>Ejemplos</b>
#             </td>
#         </tr>
#     </tbody>
# </table>
